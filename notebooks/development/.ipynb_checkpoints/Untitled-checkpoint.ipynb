# %%
# %load_ext autoreload
# %autoreload 2
import os
# Set environment variables
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".99"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import jax
# from jax import config
# config.update('jax_enable_x64', True)

# Check JAX configuration
devices = jax.local_devices()
print(devices)
print(jax.default_backend())
print(jax.devices())

import sys
# Add custom path
sys.path.append("/pchem-data/meuwly/boittier/home/pycharmm_test/src")

# from model import EF
# from loss import dipole_calc
# from  training import train_model # from model import dipole_calc
import jax
import optax
import e3x

# from dcmnet.analysis import create_model_and_params
# from data import prepare_batches, prepare_datasets
import numpy as np

import orbax
from orbax.checkpoint import PyTreeCheckpointer
orbax_checkpointer = orbax.checkpoint.PyTreeCheckpointer()
# Out:
# [CudaDevice(id=0)]
# gpu
# [CudaDevice(id=0)]

# %%
from pathlib import Path

# path = Path("/pchem-data/meuwly/boittier/home/pycharmm_test/ckpts/adp-1c07d6ad-7a43-4cf6-afd2-f9c76ff0ce7b")
# path = Path("/pchem-data/meuwly/boittier/home/pycharmm_test/ckpts/aaa-ec3e940b-642e-4558-b670-a3c10bb33176")
# path = Path("/pchem-data/meuwly/boittier/home/pycharmm_test/ckpts/test-4fd66a4e-1c54-484e-a7b6-52fca8cb23d3")
path = Path("/pchem-data/meuwly/boittier/home/pycharmm_test/ckpts/cf3all-74f8f50d-f2d1-4538-8016-19905047ec58")
path = Path("/pchem-data/meuwly/boittier/home/pycharmm_test/ckpts/cf3all-d58b8698-f2b6-4b53-bb12-337b2bf70459")

# path = Path("/pchem-data/meuwly/boittier/home/pycharmm_test/ckpts/aaa1-0b2547d6-a0b2-4c0e-be28-555f40de9bd2")

# %%
files = list(path.glob("*"))
files.sort(key=lambda x: int(str(x).split("-")[-1]))
print(len(files))
filesToDo = files[-20::] + files[-2:-1]
# filesToDo
# Out:
# 33

# %%
# from orbax.checkpoint import PyTreeRestoreArgs
from tqdm import tqdm
# restore_args = PyTreeRestoreArgs()  # Adjust arguments as needed
# restored = orbax_checkpointer.restore(path / "epoch-1", args=restore_args)
epochs = []
lr_effs = []
restored_objectives = []
filesToDo = files[:4] + files[::] + files[-2:-1]
for _ in tqdm(filesToDo):
    re = orbax_checkpointer.restore(_)
    epochs.append(int(re["epoch"]))
    lr_effs.append(float(re["lr_eff"]))
    restored_objectives.append(re["objectives"])
# Out:
#   0%|                                                                                                                                                                                                                                                              | 0/38 [00:00<?, ?it/s]/pchem-data/meuwly/boittier/home/miniforge3/envs/jaxphyscharmm/lib/python3.12/site-packages/orbax/checkpoint/type_handlers.py:1372: UserWarning: Couldn't find sharding info under RestoreArgs. Populating sharding info from sharding file. Please note restoration time will be slightly increased due to reading from file instead of directly from RestoreArgs. Note also that this option is unsafe when restoring on a different topology than the checkpoint was saved with.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:17<00:00,  2.18it/s]

# %%
restored_objectives[0]
# Out:
# {'train_energy_mae': Array(127.716576, dtype=float32),
#  'train_forces_mae': Array(20.98093, dtype=float32),
#  'train_loss': Array(610.357, dtype=float32),
#  'valid_energy_mae': Array(704.8765, dtype=float32),
#  'valid_forces_mae': Array(34.10081, dtype=float32),
#  'valid_loss': Array(1416.1311, dtype=float32)}

# %%
import pandas as pd

df = pd.DataFrame({"epoch": epochs, 
             "lr": lr_effs,
             "train_loss": [float(_["train_loss"]) for _ in restored_objectives],
             "valid_loss": [float(_["valid_loss"]) for _ in restored_objectives],
             "train_energy_mae": [float(_["train_energy_mae"]) for _ in restored_objectives],
             "train_forces_mae": [float(_["train_forces_mae"]) for _ in restored_objectives],
              "valid_energy_mae": [float(_["valid_energy_mae"]) for _ in restored_objectives],
              "valid_forces_mae": [float(_["valid_forces_mae"]) for _ in restored_objectives],
             })

# %%
df = df.sort_values(by="epoch")
import matplotlib.pyplot as plt
df.plot("epoch", ["train_loss", "valid_loss"], "line", style="-o")
plt.ylim(0,20)
df.plot("epoch", ["train_energy_mae", "valid_energy_mae"], style="-o")
plt.ylim(0,40)
plt.show()
df.plot("epoch", ["train_forces_mae", "valid_forces_mae"], style="-o")
plt.ylim(0,10)
plt.show()
df.plot("epoch", ["lr"], style="-o")
# plt.ylim(0,10)
plt.show()
df
# Out:
#    epoch        lr  train_loss   valid_loss  train_energy_mae  \
# 0      1  0.000670  610.356995  1416.131104        127.716576
# 4      1  0.000670  610.356995  1416.131104        127.716576
# 1      2  0.000681  374.706207   806.851624         51.991676
# 2      3  0.000698  342.046265   464.213928         54.817093
# 3      4  0.000722  326.573669   383.464996         52.121094
# 5     38  0.000509  189.385956   225.586441         29.021019
#
#    train_forces_mae  valid_energy_mae  valid_forces_mae
# 0         20.980930        704.876526         34.100811
# 4         20.980930        704.876526         34.100811
# 1         15.267134        480.430664         25.525557
# 2         14.172419        184.838028         17.423405
# 3         13.590811         52.349243         14.181371
# 5          8.366064         16.528929          8.337724

# %%
from orbax.checkpoint.metadata import StringMetadata
from orbax.checkpoint import PyTreeCheckpointer
import orbax.checkpoint as ocp
import jax
from jax.sharding import SingleDeviceSharding

# Initialize checkpointer
orbax_checkpointer = PyTreeCheckpointer()

# Get metadata
metadata = orbax_checkpointer.metadata(path / "epoch-1")

# Create a CPU-compatible structure
cpu_device = jax.devices("cpu")[0]
sharding = SingleDeviceSharding(cpu_device)
print(sharding)

def create_shape_dtype_struct(x):
    from orbax.checkpoint.metadata.value import StringMetadata, ScalarMetadata

    if isinstance(x, jax.ShapeDtypeStruct):
        # print(x)
        return jax.ShapeDtypeStruct(shape=x.shape, dtype=x.dtype, sharding=sharding)
        
    elif isinstance(x, ScalarMetadata):
        # Handle ScalarMetadata as scalars
        return jax.ShapeDtypeStruct(shape=(), dtype=jax.numpy.float32, sharding=sharding)
    
    elif isinstance(x, StringMetadata):
        # Replace StringMetadata with its value or a placeholder
        return jax.ShapeDtypeStruct(shape=(), dtype=jax.numpy.float32, sharding=sharding)
        
    elif hasattr(x, 'shape') and hasattr(x, 'dtype'):
        return jax.ShapeDtypeStruct(shape=x.shape, dtype=x.dtype, sharding=sharding)
    
    else:
        raise ValueError(f"Unsupported metadata type: {type(x)}")


def wrap(x):
    o = create_shape_dtype_struct(x)
    if o.sharding is None:
        print(o)
    return o

item = jax.tree.map(wrap, metadata)

# Restore the checkpoint
# restored = orbax_checkpointer.restore(path / "epoch-1", item=item)
# Out:
# SingleDeviceSharding(device=CpuDevice(id=0), memory_kind=unpinned_host)

# %%
item.keys()
_item = {"objectives": item["objectives"]}
_item
# Out:
# {'objectives': {'train_energy_mae': ShapeDtypeStruct(shape=(), dtype=float32, sharding=SingleDeviceSharding(device=CpuDevice(id=0), memory_kind=unpinned_host)),
#   'train_forces_mae': ShapeDtypeStruct(shape=(), dtype=float32, sharding=SingleDeviceSharding(device=CpuDevice(id=0), memory_kind=unpinned_host)),
#   'train_loss': ShapeDtypeStruct(shape=(), dtype=float32, sharding=SingleDeviceSharding(device=CpuDevice(id=0), memory_kind=unpinned_host)),
#   'valid_energy_mae': ShapeDtypeStruct(shape=(), dtype=float32, sharding=SingleDeviceSharding(device=CpuDevice(id=0), memory_kind=unpinned_host)),
#   'valid_forces_mae': ShapeDtypeStruct(shape=(), dtype=float32, sharding=SingleDeviceSharding(device=CpuDevice(id=0), memory_kind=unpinned_host)),
#   'valid_loss': ShapeDtypeStruct(shape=(), dtype=float32, sharding=SingleDeviceSharding(device=CpuDevice(id=0), memory_kind=unpinned_host))}}

# %%
from flax.training import orbax_utils

ckptr = orbax.checkpoint.Checkpointer(orbax.checkpoint.PyTreeCheckpointHandler())  # A stateless object, can be created on the fly.
# ckptr.save(PURE_CKPT_DIR, CKPT_PYTREE,
#            save_args=flax.training.orbax_utils.save_args_from_target(CKPT_PYTREE), force=True)
ckptr.restore(path / "epoch-1", item=item,
              # restore_args=item,
              restore_args=flax.training.orbax_utils.restore_args_from_target(item, mesh=None)
             )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 8
#       3 ckptr = orbax.checkpoint.Checkpointer(orbax.checkpoint.PyTreeCheckpointHandler())  # A stateless object, can be created on the fly.
#       4 # ckptr.save(PURE_CKPT_DIR, CKPT_PYTREE,
#       5 #            save_args=flax.training.orbax_utils.save_args_from_target(CKPT_PYTREE), force=True)
#       6 ckptr.restore(path / "epoch-1", item=item,
#       7               # restore_args=item,
# ----> 8               restore_args=flax.training.orbax_utils.restore_args_from_target(item, mesh=None)
#       9              )
#
# NameError: name 'flax' is not defined

# %%
abstract_state = jax.tree_util.tree_map(ocp.utils.to_shape_dtype_struct, item)
abstract_state

# %%
# ckptr = ocp.AsyncCheckpointer(ocp.PyTreeCheckpointHandler())
# ocp.PyTreeCheckpointHandler().restore(path / "epoch-1", args=item)
restored = orbax_checkpointer.restore(path / "epoch-1", args=composite_args)

# %%
mngr = ocp.CheckpointManager(path)

# %%
dir(mngr)

# %%
mngr.restore("epoch-10", args=composite_args)

# %%
from orbax.checkpoint import args

# Assuming `abstract_state` is a dictionary of objects to restore
composite_args = args.Composite(**abstract_state)

# %%
len(abstract_state)
rstargs = {}
for k in abstract_state.keys():
    if isinstance(abstract_state[k], dict):
        _ = { v: ocp.ArrayRestoreArgs(dtype=np.dtype(np.int16), sharding=sharding)
                  for v in abstract_state[k].keys()}
    else:
        _ = { k: ocp.ArrayRestoreArgs(dtype=np.dtype(np.int16), sharding=sharding)}
    rstargs[k] = _

# %%
rstargs

# %%
ckptr = ocp.AsyncCheckpointer(ocp.PyTreeCheckpointHandler())

# %%
ckptr.restore(
    path / 'epoch-1',
    args=ocp.args.PyTreeRestore(
        restore_args=rstargs
    ),
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 ckptr.restore(
#       2     path / 'epoch-1',
#       3     args=ocp.args.PyTreeRestore(
#       4         restore_args=rstargs
#       5     ),
#       6 )
#
# File ~/miniforge3/envs/jaxphyscharmm/lib/python3.12/site-packages/orbax/checkpoint/async_checkpointer.py:428, in AsyncCheckpointer.restore(self, directory, *args, **kwargs)
#     426 """See superclass documentation."""
#     427 self.wait_until_finished()
# --> 428 return super().restore(directory, *args, **kwargs)
#
# File ~/miniforge3/envs/jaxphyscharmm/lib/python3.12/site-packages/orbax/checkpoint/checkpointer.py:239, in Checkpointer.restore(self, directory, *args, **kwargs)
#     237 logging.info('Restoring checkpoint from %s.', directory)
#     238 ckpt_args = construct_checkpoint_args(self._handler, False, *args, **kwargs)
# --> 239 restored = self._handler.restore(directory, args=ckpt_args)
#     240 logging.info('Finished restoring checkpoint from %s.', directory)
#     241 multihost.sync_global_processes(
#     242     multihost.unique_barrier_key(
#     243         'Checkpointer:restore',
#    (...)
#     247     processes=self._active_processes,
#     248 )
#
# File ~/miniforge3/envs/jaxphyscharmm/lib/python3.12/site-packages/orbax/checkpoint/_src/handlers/pytree_checkpoint_handler.py:766, in PyTreeCheckpointHandler.restore(self, directory, item, restore_args, transforms, transforms_default_to_original, legacy_transform_fn, args)
#     756 if (
#     757     (directory / PYTREE_METADATA_FILE).exists()
#     758     and can_ignore_aggregate_file
#     759     and transforms is None
#     760     and legacy_transform_fn is None
#     761 ):
#     762   args = BasePyTreeRestoreArgs(
#     763       item,
#     764       restore_args=restore_args,
#     765   )
# --> 766   return self._handler_impl.restore(directory, args=args)
#     768 logging.vlog(1, 'directory=%s, restore_args=%s', directory, restore_args)
#     769 if not directory.exists():
#
# File ~/miniforge3/envs/jaxphyscharmm/lib/python3.12/site-packages/orbax/checkpoint/_src/handlers/base_pytree_checkpoint_handler.py:657, in BasePyTreeCheckpointHandler.restore(self, directory, args)
#     655 if item is None:
#     656   item = metadata
# --> 657 restore_args = _fill_missing_save_or_restore_args(
#     658     item, restore_args, mode='restore'
#     659 )
#     660 restore_args = tree_utils.serialize_tree(
#     661     restore_args, keep_empty_nodes=True
#     662 )
#     663 use_zarr3 = (
#     664     use_zarr3_metadata
#     665     if use_zarr3_metadata is not None
#     666     else self._use_zarr3
#     667 )
#
# File ~/miniforge3/envs/jaxphyscharmm/lib/python3.12/site-packages/orbax/checkpoint/_src/handlers/base_pytree_checkpoint_handler.py:251, in _fill_missing_save_or_restore_args(item, args, mode)
#     248   else:
#     249     raise ValueError(f'Unknown mode: {mode}.')
# --> 251 return jax.tree_util.tree_map(
#     252     _maybe_set_default_save_args,
#     253     item,
#     254     item if args is None else args,
#     255     is_leaf=utils.is_empty_or_leaf,
#     256 )
#
# File ~/miniforge3/envs/jaxphyscharmm/lib/python3.12/site-packages/jax/_src/tree_util.py:343, in tree_map(f, tree, is_leaf, *rest)
#     341 """Alias of :func:`jax.tree.map`."""
#     342 leaves, treedef = tree_flatten(tree, is_leaf)
# --> 343 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
#     344 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# ValueError: Expected dict, got ArrayRestoreArgs(restore_type=<class 'jax.Array'>, dtype=dtype('int16'), mesh=None, mesh_axes=None, sharding=SingleDeviceSharding(device=CpuDevice(id=0), memory_kind=unpinned_host), global_shape=None).
